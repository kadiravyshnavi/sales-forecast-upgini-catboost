# %%
import pandas as pd

# %%
# Results from experiments

baseline_smape = 37.65   # ← paste BASELINE SMAPE from baseline notebook
upgini_smape = 26.79     # ← paste UPGINI SMAPE you just got

# %%
comparison = pd.DataFrame({
    "Model": ["Baseline CatBoost", "CatBoost + Upgini"],
    "SMAPE": [baseline_smape, upgini_smape]
})

comparison
# Out:
#                Model  SMAPE
# 0  Baseline CatBoost  37.65
# 1  CatBoost + Upgini  26.79

# %%
improvement = ((baseline_smape - upgini_smape) / baseline_smape) * 100
f"SMAPE improved by {improvement:.2f}% using Upgini feature enrichment"
# Out:
# 'SMAPE improved by 28.84% using Upgini feature enrichment'

# %%
comparison.to_csv("baseline_vs_upgini_metrics.csv", index=False)
